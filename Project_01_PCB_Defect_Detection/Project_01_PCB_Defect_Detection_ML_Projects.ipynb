# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/PCB_Defect_Detection_ML_Projects/blob/main/Project_01_PCB_Defect_Detection/Project_01_PCB_Defect_Detection_ML_Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Command to install OpenCV library :
# pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next, I'll clone the repository and copy the image folders to your Google Drive.

# %%
import os

# Clone the repository to a temporary location
# !git clone https://github.com/swaralipaygude/Bare-PCB-defect-detection-using-OpenCV.git /tmp/Bare-PCB-defect-detection-using-OpenCV

# List the contents of the cloned repository to find the correct path to the image dataset
print("Contents of cloned repository:")
# !ls /tmp/Bare-PCB-defect-detection-using-OpenCV

# List contents of the 'Bare-PCB-images-dataset' to verify its structure
print("Contents of Bare-PCB-images-dataset:")
# !ls /tmp/Bare-PCB-defect-detection-using-OpenCV/Bare-PCB-images-dataset

# Based on inspection, it appears the actual dataset is directly inside the cloned repo
# without an intermediate 'Bare-PCB-images-dataset' folder within the cloned repo.
# So, the source_dir should be directly the cloned repo path for the folders.
source_dir_base = '/tmp/Bare-PCB-defect-detection-using-OpenCV/Bare-PCB-images-dataset'
dest_dir = '/content/drive/MyDrive/Bare-PCB-images-dataset'

# Create the destination directory in Google Drive if it doesn't exist
os.makedirs(dest_dir, exist_ok=True)

# --- BEGIN MODIFICATION ---
# Copy the 'Defective-PCB-images' and 'Template-PCB-images' folders to Google Drive
# !cp -r {source_dir_base}/Defective-PCB-images {dest_dir}/
# !cp -r {source_dir_base}/Template-PCB-images {dest_dir}/

print(f"Image folders copied to: {dest_dir}")

# Verify the content (optional)
print("Content of Defective-PCB-images folder in Drive:")
# !ls {dest_dir}/Defective-PCB-images | head -5
print("Content of Template-PCB-images folder in Drive:")
# !ls {dest_dir}/Template-PCB-images | head -5
# --- END MODIFICATION ---
# Out:
# fatal: destination path '/tmp/Bare-PCB-defect-detection-using-OpenCV' already exists and is not an empty directory.
# Contents of cloned repository:
# Bare-PCB-defect-detection-using-opencv.ipynb  IJRASET35775-published-paper.pdf
# Bare-PCB-images-dataset			      README.md
# Final-Project-Report.pdf
# Contents of Bare-PCB-images-dataset:
# Defective-PCB-images  Template-PCB-images
# Image folders copied to: /content/drive/MyDrive/Bare-PCB-images-dataset
# Content of Defective-PCB-images folder in Drive:
# Missing_hole
# Mouse_bite
# Open_circuit
# README.md
# Content of Template-PCB-images folder in Drive:
# 01_180.JPG
# 01.JPG
# 01_left.JPG
# 01_right.JPG
# 05_180.JPG

# %% [markdown]
# The 'good' and 'bad' image folders are now available in your Google Drive at `'/content/drive/MyDrive/Bare-PCB-images-dataset/'`. You can access them directly from your notebook.

# %%
rgb_template_img = cv2.imread('/content/drive/MyDrive/Bare-PCB-images-dataset/Template-PCB-images/01.JPG')

# display original template PCB image
plt.figure(figsize=(10,6))
plt.imshow(rgb_template_img, cmap="gray")

# %%
template_img = cv2.imread('/content/drive/MyDrive/Bare-PCB-images-dataset/Template-PCB-images/01.JPG', 0)

plt.figure(figsize=(10, 6))
plt.imshow(template_img, cmap='gray')

# %%
template_img_resize = cv2.resize(template_img, (750, 450))

plt.figure(figsize=(10,6))
plt.imshow(template_img_resize, cmap="gray")
